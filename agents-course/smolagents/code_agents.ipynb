# %% [markdown]
# 1. Using default tool and model

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=InferenceClientModel())

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music for party at mansion")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Groovy Disco and R&B Mix at a New York Mansion Party | Tinzo -
# YouTube](https://www.youtube.com/watch?v=c70ZRfvmHuo)
# Book Club Meeting #18: Tinzo plays a mix of disco classics for our murder mystery-themed party at a mansion in New
# York City. Can you unveil the perpertrator... Published July 18, 2024
#
# [house party hype - playlist by megannnlizz | Spotify](https://open.spotify.com/playlist/1Z4LcMgalKtQBlRy59YWEY)
# Playlist · house party hype · 157 items · 2.1K saves
#
# [The top ten perfect house party tunes -
# Mixmag.net](https://mixmag.net/feature/the-top-ten-perfect-house-party-tunes)
# Staying on a Dance Mania tip, ' Get Get Down' by Paul Johnson is, dare we say it, the best party tune of all time.
# Play it at the start, play it in the middle, play it at the end.
#
# [House Party on Apple Music](https://music.apple.com/us/playlist/house-party/pl.442baf6c30d34dcdb4a3d852e445b173)
# September 19, 2025 - Listen to the House Party playlist on Apple Music. 100 Songs. Duration: 6 hours 6 minutes.
#
# [Best Party Songs - House Party Music Playlist (Updated in 2026) -
# YouTube](https://www.youtube.com/playlist?list=PLo3pNg0eiPc-3MC9VFxy9Kt6eau9ZJTPt)
# Best Party Songs - House Party Music Playlist (Updated in 2026) If you liked this playlist, we recommend you also
# listen to these music lists: 1. Summer Pool...
#
# [What are some good tracks for house parties? -
# Quora](https://www.quora.com/What-are-some-good-tracks-for-house-parties)
# Answer (1 of 4): The Way You Move - OutKast Bad Boys- Inner Circle Party Rock Anthem- LMFAO Three Little Birds-
# Ziggy Marley and Sean Paul Feel So Close- Calvin Harris Alone- Marshmello California Love- 2Pac and Dr.
#
# [200 Classic House Party Songs Everyone Knows | The Best Popular Party
# Songs](https://www.ispytunes.com/post/house-party-songs)
# December 13, 2024 - Brightside" by The Killers is one of the most recognizable songs of all time—for good reason!
# It has an upbeat melody that's catchy and energizing, plus some pretty insightful lyrics about jealousy and
# insecurity. Its popularity transcends multiple generations, so it's no surprise that it is a staple at parties
# everywhere. Everyone can appreciate both its relatable lyrical content and its energetic sound—whether it's playing
# as background music or people are singing along with every word.
#
# [House Party Classics](https://open.spotify.com/playlist/37i9dQZF1DWSloWsJ4C894)
# Spotify is unavailable on this browser. For the best listening experience update your browser or download the
# Spotify app
#
# [House Party 2021 playlist | Listen on Deezer](https://www.deezer.com/us/playlist/6279702364)
# by Musical Freedom | Public | Non-collaborative · "Keep the party going at home with the best house & dance anthems
# of 2021. Updated weekly!" 80 tracks - 4 h 04 min ·
#
# [House Party w/ Confidence Man | Spotify Playlist](https://open.spotify.com/playlist/37i9dQZF1DXd5DCuoVuFY3)
# Playlist · House Party w/ Confidence Man · 50 items · 610.1K saves
#
# Out: None
# [Step 1: Duration 9.81 seconds| Input tokens: 2,090 | Output tokens: 921]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("The best music recommendations for a Wayne's mansion party are the 'Groovy Disco and R&B Mix' on
#   YouTube by Tinzo, featuring classic disco and R&B tracks, alongside top party songs such as 'Get Get Down' by
#   Paul Johnson, 'Brightside' by The Killers, and 'California Love' by 2Pac & Dr. Dre.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: The best music recommendations for a Wayne's mansion party are the 'Groovy Disco and R&B Mix' on
# YouTube by Tinzo, featuring classic disco and R&B tracks, alongside top party songs such as 'Get Get Down' by Paul
# Johnson, 'Brightside' by The Killers, and 'California Love' by 2Pac & Dr. Dre.
# [Step 2: Duration 19.33 seconds| Input tokens: 5,192 | Output tokens: 3,714]
# "The best music recommendations for a Wayne's mansion party are the 'Groovy Disco and R&B Mix' on YouTube by Tinzo, featuring classic disco and R&B tracks, alongside top party songs such as 'Get Get Down' by Paul Johnson, 'Brightside' by The Killers, and 'California Love' by 2Pac & Dr. Dre."

# %% [markdown]
# 2. Using a custom tool

# %%
from smolagents import CodeAgent, tool, InferenceClientModel

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

agent = CodeAgent(tools=[suggest_menu], model=InferenceClientModel())
agent.run("Prepare a formal menu for the party")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Prepare a formal menu for the party                                                                             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(occasion="formal")
#   final_answer(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3-course dinner with wine and dessert.
# [Step 1: Duration 4.24 seconds| Input tokens: 2,111 | Output tokens: 438]
# '3-course dinner with wine and dessert.'

# %% [markdown]
# 3. Use Python import

# %%
from smolagents import CodeAgent, InferenceClientModel
import numpy as np
import time
import datetime

agent = CodeAgent(tools=[], model=InferenceClientModel(), additional_authorized_imports=['datetime'])

agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    4. Prepare the music and playlist - 45 minutes

    If we start right now, at what specific time will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     4. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what specific time will the party be ready?                                       │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import datetime
#
#   total_minutes = 30 + 60 + 45 + 45
#   current_time = datetime.datetime.now()
#   end_time = current_time + datetime.timedelta(minutes=total_minutes)
#   final_answer(end_time.strftime("%H:%M"))
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 09:44
# [Step 1: Duration 14.13 seconds| Input tokens: 2,112 | Output tokens: 2,913]
# '09:44'
